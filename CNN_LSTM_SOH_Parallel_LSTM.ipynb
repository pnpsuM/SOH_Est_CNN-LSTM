# %% [markdown]
# ## 0.Import Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd "/content/drive/My Drive/Colab Notebooks/SOH_Est_CNN-LSTM"
# Out:
# /content/drive/My Drive/Colab Notebooks/SOH_Est_CNN-LSTM

# %% [markdown]
# ## 1.Import Library

# %%
from SOH_func_scaler import *
import matplotlib.pyplot as pl
from keras import models, layers
import tensorflow as tf
from keras.callbacks import ModelCheckpoint
from keras.callbacks import TensorBoard
import datetime
import os

# %load_ext tensorboard

from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, Activation

# %% [markdown]
# ## 2. Load Dataset

# %%
VERSION = 'FINAL' # 띄어쓰기 없이 어떤 모델인지 버전을 써주세요

FILE_00 = 'data_csv/CYCLE_CSV_data00.csv'
FILE_01 = 'data_csv/CYCLE_CSV_data01.csv'
FILE_02 = 'data_csv/CYCLE_CSV_data02.csv'
FILE_03 = 'data_csv/CYCLE_CSV_data03.csv'
FILE_04 = 'data_csv/CYCLE_CSV_data04.csv'
FILE_05 = 'data_csv/CYCLE_CSV_data05.csv'
FILE_06 = 'data_csv/CYCLE_CSV_data06.csv'

# %%
drop_labels_x = ['인덱스', '사이클_번호', '누적_용량(Ah)', '누적_에너지(Wh)', '쿨롱_효율(%)', '에너지_효율(%)', '최대_전압(V)', '충전_최종전압(V)', '단위_충전_용량(Ah/g)', '방전_최종전압(V)', '단위_방전_용량(Ah/g)']
drop_labels_y = ['인덱스', '사이클_번호', '충전_용량(Ah)', '누적_용량(Ah)', '충전_에너지(Wh)', '방전_에너지(Wh)', '누적_에너지(Wh)', '쿨롱_효율(%)', '에너지_효율(%)', '최대_전압(V)', '충전_최종전압(V)', '방전_최종전압(V)', '단위_충전_용량(Ah/g)', '방전_최종전압(V)', '단위_방전_용량(Ah/g)']
# 예측에 사용하지 않을 파라미터 목록

param = {'seq_len' : 20, 'num_units' : 64, 'num_filters' : 64, 'window' : 3, 'dropout': 0.1, 'num_epochs' : 20, 'num_dense': 16}
# 모델 규격 지정 하이퍼파라미터

log_dir = f"logs/{VERSION}/" + datetime.datetime.now().strftime("%Y%m%d-%H%M") + f'-{param["num_filters"]}FL-{param["num_units"]}UN-{param["num_epochs"]}EP-{param["seq_len"]}SQ'
file_path = f'Checkpoints\{VERSION}\SOH_Checkpoint\{param["num_filters"]}FL-{param["num_units"]}UN-{param["num_epochs"]}EP-{param["seq_len"]}SQ.h5'
hist_freq = 250
# 텐서보드 설정(logs 폴더에 모델 학습 기록 저장)

save_path = f'outputs\{VERSION}\{param["num_filters"]}FL-{param["num_units"]}UN-{param["num_epochs"]}EP-{param["seq_len"]}SQ'
try:
    if not os.path.exists(save_path):
        os.makedirs(save_path)
except OSError:
    print('Error Creating Directory...')
# 출력 저장 폴더 생성

# %% [markdown]
# ## 3. Split train and test dataset

# %%
data00, data_cap00 = get_data(FILE_00, drop_labels_x, drop_labels_y)
data01, data_cap01 = get_data(FILE_01, drop_labels_x, drop_labels_y)
data02, data_cap02 = get_data(FILE_02, drop_labels_x, drop_labels_y)
data04, data_cap04 = get_data(FILE_05, drop_labels_x, drop_labels_y)
data_test, data_cap_test = get_data(FILE_04, drop_labels_x, drop_labels_y)
# 쓸 데이터만 뽑아서 저장(입력 데이터, 정답 데이터)
# Out:
# Index(['충전_용량(Ah)', '방전_용량(Ah)', '충전_에너지(Wh)', '방전_에너지(Wh)'], dtype='object')
# Index(['방전_용량(Ah)'], dtype='object')
# data_csv/CYCLE_CSV_data00.csv => (475, 4)
# Index(['충전_용량(Ah)', '방전_용량(Ah)', '충전_에너지(Wh)', '방전_에너지(Wh)'], dtype='object')
# Index(['방전_용량(Ah)'], dtype='object')
# data_csv/CYCLE_CSV_data01.csv => (515, 4)
# Index(['충전_용량(Ah)', '방전_용량(Ah)', '충전_에너지(Wh)', '방전_에너지(Wh)'], dtype='object')
# Index(['방전_용량(Ah)'], dtype='object')
# data_csv/CYCLE_CSV_data02.csv => (515, 4)
# Index(['충전_용량(Ah)', '방전_용량(Ah)', '충전_에너지(Wh)', '방전_에너지(Wh)'], dtype='object')
# Index(['방전_용량(Ah)'], dtype='object')
# data_csv/CYCLE_CSV_data05.csv => (515, 4)
# Index(['충전_용량(Ah)', '방전_용량(Ah)', '충전_에너지(Wh)', '방전_에너지(Wh)'], dtype='object')
# Index(['방전_용량(Ah)'], dtype='object')
# data_csv/CYCLE_CSV_data04.csv => (515, 4)

# %%
x_train00 = seq_gen_x(data00, param['seq_len'])
y_train00 = seq_gen_y(data_cap00, param['seq_len'])
x_train01 = seq_gen_x(data01, param['seq_len'])
y_train01 = seq_gen_y(data_cap01, param['seq_len'])
x_train02 = seq_gen_x(data02, param['seq_len'])
y_train02 = seq_gen_y(data_cap02, param['seq_len'])
x_train04 = seq_gen_x(data04, param['seq_len'])
y_train04 = seq_gen_y(data_cap04, param['seq_len'])
x_test = seq_gen_x(data_test, param['seq_len'])
y_test = seq_gen_y(data_cap_test, param['seq_len'])
print(x_train00.shape)
print(y_train00.shape)
print(x_train01.shape)
print(x_train02.shape)
print(x_train04.shape)
# print(x_train00[0:5, :, 1])
# print(y_train00[:4])
# 시퀀스 단위로 쪼개기
# Out:
# (455, 20, 4)
# (455, 1, 1)
# (495, 20, 4)
# (495, 20, 4)
# (495, 20, 4)

# %% [markdown]
# ## 4. Training with LSTM

# %%
inputs = layers.Input(shape=(x_train00.shape[-2], x_train00.shape[-1]), name = 'Inputs')
x1 = layers.LSTM(param['num_units'], return_sequences = True)(inputs)
x2 = layers.LSTM(param['num_units'], return_sequences = True)(inputs)
x1 = layers.LSTM(16)(x1)
x1 = layers.Dropout(param['dropout'])(x1)
x2 = layers.LSTM(16)(x2)
x2 = layers.Dropout(param['dropout'])(x2)
x = layers.concatenate([x1, x2])
outputs = layers.Dense(1)(x)
model = models.Model(inputs = inputs, outputs = outputs, name = 'CNN_LSTM_PARALLEL')
model.compile(loss = 'mse', optimizer = 'Adam')
model.summary()
# Out:
# Model: "CNN_LSTM_PARALLEL"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Inputs (InputLayer)            [(None, 20, 4)]      0           []
#
#  lstm (LSTM)                    (None, 20, 64)       17664       ['Inputs[0][0]']
#
#  lstm_1 (LSTM)                  (None, 20, 64)       17664       ['Inputs[0][0]']
#
#  lstm_2 (LSTM)                  (None, 16)           5184        ['lstm[0][0]']
#
#  lstm_3 (LSTM)                  (None, 16)           5184        ['lstm_1[0][0]']
#
#  dropout (Dropout)              (None, 16)           0           ['lstm_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 16)           0           ['lstm_3[0][0]']
#
#  concatenate (Concatenate)      (None, 32)           0           ['dropout[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  dense (Dense)                  (None, 1)            33          ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 45,729
# Trainable params: 45,729
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
BATCH_SIZE = 32
callback_list = [ModelCheckpoint(filepath = file_path, monitor = 'val_loss', save_best_only = True),
                 TensorBoard(log_dir=log_dir, histogram_freq=hist_freq)]
fitdata = model.fit(x_train00, y_train00, epochs=param['num_epochs'], verbose = 2, batch_size=BATCH_SIZE, validation_split=0.2, callbacks=callback_list)
callback_list = [ModelCheckpoint(filepath = file_path, monitor = 'val_loss', save_best_only = True),
                 TensorBoard(log_dir=log_dir, histogram_freq=hist_freq)]
fitdata = model.fit(x_train01, y_train01, epochs=param['num_epochs'], verbose = 2, batch_size=BATCH_SIZE, validation_split=0.2, callbacks=callback_list)
callback_list = [ModelCheckpoint(filepath = file_path, monitor = 'val_loss', save_best_only = True),
                 TensorBoard(log_dir=log_dir, histogram_freq=hist_freq)]
fitdata = model.fit(x_train02, y_train02, epochs=param['num_epochs'], verbose = 2, batch_size=BATCH_SIZE, validation_split=0.2, callbacks=callback_list)
callback_list = [ModelCheckpoint(filepath = file_path, monitor = 'val_loss', save_best_only = True),
                 TensorBoard(log_dir=log_dir, histogram_freq=hist_freq)]
fitdata = model.fit(x_train04, y_train04, epochs=param['num_epochs'], verbose = 2, batch_size=BATCH_SIZE, validation_split=0.2, callbacks=callback_list)
# Out:
# Epoch 1/20
# 12/12 - 12s - loss: 0.0349 - val_loss: 1.5360e-05 - 12s/epoch - 1s/step
# Epoch 2/20
# 12/12 - 0s - loss: 0.0084 - val_loss: 4.1620e-05 - 171ms/epoch - 14ms/step
# Epoch 3/20
# 12/12 - 0s - loss: 0.0057 - val_loss: 1.2948e-04 - 149ms/epoch - 12ms/step
# Epoch 4/20
# 12/12 - 0s - loss: 0.0032 - val_loss: 3.3953e-04 - 159ms/epoch - 13ms/step
# Epoch 5/20
# 12/12 - 0s - loss: 0.0031 - val_loss: 9.2814e-04 - 149ms/epoch - 12ms/step
# Epoch 6/20
# 12/12 - 0s - loss: 0.0027 - val_loss: 2.5172e-04 - 152ms/epoch - 13ms/step
# Epoch 7/20
# 12/12 - 0s - loss: 0.0035 - val_loss: 6.7918e-05 - 159ms/epoch - 13ms/step
# Epoch 8/20
# 12/12 - 0s - loss: 0.0029 - val_loss: 5.5502e-05 - 164ms/epoch - 14ms/step
# Epoch 9/20
# 12/12 - 0s - loss: 0.0029 - val_loss: 1.3237e-05 - 233ms/epoch - 19ms/step
# Epoch 10/20
# 12/12 - 0s - loss: 0.0031 - val_loss: 1.1449e-05 - 222ms/epoch - 18ms/step
# Epoch 11/20
# 12/12 - 0s - loss: 0.0026 - val_loss: 1.1460e-04 - 148ms/epoch - 12ms/step
# Epoch 12/20
# 12/12 - 0s - loss: 0.0022 - val_loss: 1.0955e-05 - 210ms/epoch - 17ms/step
# Epoch 13/20
# 12/12 - 0s - loss: 0.0024 - val_loss: 2.4432e-05 - 148ms/epoch - 12ms/step
# Epoch 14/20
# 12/12 - 0s - loss: 0.0023 - val_loss: 2.5649e-06 - 207ms/epoch - 17ms/step
# Epoch 15/20
# 12/12 - 0s - loss: 0.0025 - val_loss: 3.3974e-05 - 160ms/epoch - 13ms/step
# Epoch 16/20
# 12/12 - 0s - loss: 0.0028 - val_loss: 5.0140e-05 - 153ms/epoch - 13ms/step
# Epoch 17/20
# 12/12 - 0s - loss: 0.0029 - val_loss: 1.6016e-05 - 153ms/epoch - 13ms/step
# Epoch 18/20
# 12/12 - 0s - loss: 0.0024 - val_loss: 1.0684e-05 - 149ms/epoch - 12ms/step
# Epoch 19/20
# 12/12 - 0s - loss: 0.0024 - val_loss: 1.5107e-04 - 153ms/epoch - 13ms/step
# Epoch 20/20
# 12/12 - 0s - loss: 0.0019 - val_loss: 1.6942e-05 - 156ms/epoch - 13ms/step
# Epoch 1/20
# 13/13 - 0s - loss: 0.0015 - val_loss: 4.5087e-05 - 353ms/epoch - 27ms/step
# Epoch 2/20
# 13/13 - 0s - loss: 0.0013 - val_loss: 1.3426e-04 - 165ms/epoch - 13ms/step
# Epoch 3/20
# 13/13 - 0s - loss: 0.0013 - val_loss: 4.7031e-04 - 161ms/epoch - 12ms/step
# Epoch 4/20
# 13/13 - 0s - loss: 0.0015 - val_loss: 6.4211e-04 - 157ms/epoch - 12ms/step
# Epoch 5/20
# 13/13 - 0s - loss: 0.0012 - val_loss: 3.3799e-04 - 208ms/epoch - 16ms/step
# Epoch 6/20
# 13/13 - 0s - loss: 0.0013 - val_loss: 7.7402e-05 - 179ms/epoch - 14ms/step
# Epoch 7/20
# 13/13 - 0s - loss: 0.0011 - val_loss: 7.4277e-05 - 169ms/epoch - 13ms/step
# Epoch 8/20
# 13/13 - 0s - loss: 0.0013 - val_loss: 1.9487e-04 - 159ms/epoch - 12ms/step
# Epoch 9/20
# 13/13 - 0s - loss: 0.0012 - val_loss: 2.8053e-04 - 162ms/epoch - 12ms/step
# Epoch 10/20
# 13/13 - 0s - loss: 0.0012 - val_loss: 7.8204e-05 - 171ms/epoch - 13ms/step
# Epoch 11/20
# 13/13 - 0s - loss: 0.0013 - val_loss: 4.6607e-05 - 166ms/epoch - 13ms/step
# Epoch 12/20
# 13/13 - 0s - loss: 0.0012 - val_loss: 1.2476e-04 - 168ms/epoch - 13ms/step
# Epoch 13/20
# 13/13 - 0s - loss: 0.0013 - val_loss: 6.0939e-04 - 162ms/epoch - 12ms/step
# Epoch 14/20
# 13/13 - 0s - loss: 0.0012 - val_loss: 4.4680e-04 - 157ms/epoch - 12ms/step
# Epoch 15/20
# 13/13 - 0s - loss: 0.0010 - val_loss: 1.2364e-04 - 197ms/epoch - 15ms/step
# Epoch 16/20
# 13/13 - 0s - loss: 0.0011 - val_loss: 3.4699e-04 - 167ms/epoch - 13ms/step
# Epoch 17/20
# 13/13 - 0s - loss: 0.0014 - val_loss: 2.2280e-04 - 172ms/epoch - 13ms/step
# Epoch 18/20
# 13/13 - 0s - loss: 0.0013 - val_loss: 8.6338e-05 - 158ms/epoch - 12ms/step
# Epoch 19/20
# 13/13 - 0s - loss: 0.0011 - val_loss: 2.5474e-04 - 172ms/epoch - 13ms/step
# Epoch 20/20
# 13/13 - 0s - loss: 0.0011 - val_loss: 2.0027e-04 - 158ms/epoch - 12ms/step
# Epoch 1/20
# 13/13 - 0s - loss: 3.0976e-04 - val_loss: 6.7466e-05 - 312ms/epoch - 24ms/step
# Epoch 2/20
# 13/13 - 0s - loss: 2.7800e-04 - val_loss: 1.8516e-05 - 215ms/epoch - 17ms/step
# Epoch 3/20
# 13/13 - 0s - loss: 1.7083e-04 - val_loss: 5.8021e-05 - 154ms/epoch - 12ms/step
# Epoch 4/20
# 13/13 - 0s - loss: 1.8865e-04 - val_loss: 2.0797e-05 - 166ms/epoch - 13ms/step
# Epoch 5/20
# 13/13 - 0s - loss: 1.9155e-04 - val_loss: 1.6079e-05 - 217ms/epoch - 17ms/step
# Epoch 6/20
# 13/13 - 0s - loss: 1.8508e-04 - val_loss: 2.0669e-05 - 157ms/epoch - 12ms/step
# Epoch 7/20
# 13/13 - 0s - loss: 1.6676e-04 - val_loss: 3.5339e-05 - 205ms/epoch - 16ms/step
# Epoch 8/20
# 13/13 - 0s - loss: 2.0595e-04 - val_loss: 5.8144e-05 - 166ms/epoch - 13ms/step
# Epoch 9/20
# 13/13 - 0s - loss: 1.8686e-04 - val_loss: 3.9786e-05 - 160ms/epoch - 12ms/step
# Epoch 10/20
# 13/13 - 0s - loss: 1.8666e-04 - val_loss: 4.8747e-05 - 160ms/epoch - 12ms/step
# Epoch 11/20
# 13/13 - 0s - loss: 1.5966e-04 - val_loss: 1.3230e-05 - 223ms/epoch - 17ms/step
# Epoch 12/20
# 13/13 - 0s - loss: 2.0157e-04 - val_loss: 3.5077e-05 - 155ms/epoch - 12ms/step
# Epoch 13/20
# 13/13 - 0s - loss: 2.0715e-04 - val_loss: 3.8776e-05 - 158ms/epoch - 12ms/step
# Epoch 14/20
# 13/13 - 0s - loss: 1.4238e-04 - val_loss: 1.8860e-05 - 165ms/epoch - 13ms/step
# Epoch 15/20
# 13/13 - 0s - loss: 1.5913e-04 - val_loss: 2.3309e-05 - 167ms/epoch - 13ms/step
# Epoch 16/20
# 13/13 - 0s - loss: 1.6031e-04 - val_loss: 1.4866e-05 - 164ms/epoch - 13ms/step
# Epoch 17/20
# 13/13 - 0s - loss: 1.6889e-04 - val_loss: 3.2451e-05 - 169ms/epoch - 13ms/step
# Epoch 18/20
# 13/13 - 0s - loss: 1.7159e-04 - val_loss: 2.0419e-05 - 163ms/epoch - 13ms/step
# Epoch 19/20
# 13/13 - 0s - loss: 1.5577e-04 - val_loss: 3.0571e-05 - 156ms/epoch - 12ms/step
# Epoch 20/20
# 13/13 - 0s - loss: 1.8632e-04 - val_loss: 1.3232e-05 - 165ms/epoch - 13ms/step
# Epoch 1/20
# 13/13 - 0s - loss: 7.0159e-04 - val_loss: 9.8589e-05 - 309ms/epoch - 24ms/step
# Epoch 2/20
# 13/13 - 0s - loss: 6.7270e-04 - val_loss: 7.8050e-05 - 222ms/epoch - 17ms/step
# Epoch 3/20
# 13/13 - 0s - loss: 5.6859e-04 - val_loss: 8.7467e-05 - 168ms/epoch - 13ms/step
# Epoch 4/20
# 13/13 - 0s - loss: 5.5899e-04 - val_loss: 1.0281e-04 - 163ms/epoch - 13ms/step
# Epoch 5/20
# 13/13 - 0s - loss: 6.0900e-04 - val_loss: 7.0841e-05 - 221ms/epoch - 17ms/step
# Epoch 6/20
# 13/13 - 0s - loss: 6.1403e-04 - val_loss: 6.8061e-05 - 232ms/epoch - 18ms/step
# Epoch 7/20
# 13/13 - 0s - loss: 5.3919e-04 - val_loss: 6.8637e-05 - 156ms/epoch - 12ms/step
# Epoch 8/20
# 13/13 - 0s - loss: 5.0339e-04 - val_loss: 1.3185e-04 - 156ms/epoch - 12ms/step
# Epoch 9/20
# 13/13 - 0s - loss: 6.7847e-04 - val_loss: 7.1735e-05 - 161ms/epoch - 12ms/step
# Epoch 10/20
# 13/13 - 0s - loss: 4.7381e-04 - val_loss: 1.0282e-04 - 204ms/epoch - 16ms/step
# Epoch 11/20
# 13/13 - 0s - loss: 5.2812e-04 - val_loss: 1.1373e-04 - 176ms/epoch - 14ms/step
# Epoch 12/20
# 13/13 - 0s - loss: 4.8271e-04 - val_loss: 7.1812e-05 - 156ms/epoch - 12ms/step
# Epoch 13/20
# 13/13 - 0s - loss: 6.4587e-04 - val_loss: 7.8725e-05 - 159ms/epoch - 12ms/step
# Epoch 14/20
# 13/13 - 0s - loss: 5.7607e-04 - val_loss: 1.0844e-04 - 155ms/epoch - 12ms/step
# Epoch 15/20
# 13/13 - 0s - loss: 5.2543e-04 - val_loss: 6.8615e-05 - 161ms/epoch - 12ms/step
# Epoch 16/20
# 13/13 - 0s - loss: 5.1596e-04 - val_loss: 7.6047e-05 - 172ms/epoch - 13ms/step
# Epoch 17/20
# 13/13 - 0s - loss: 5.9579e-04 - val_loss: 6.8116e-05 - 165ms/epoch - 13ms/step
# Epoch 18/20
# 13/13 - 0s - loss: 5.3852e-04 - val_loss: 1.2374e-04 - 180ms/epoch - 14ms/step
# Epoch 19/20
# 13/13 - 0s - loss: 6.8715e-04 - val_loss: 1.9443e-04 - 164ms/epoch - 13ms/step
# Epoch 20/20
# 13/13 - 0s - loss: 6.6636e-04 - val_loss: 7.5947e-05 - 165ms/epoch - 13ms/step

# %% [markdown]
# ## 5. Result Visualization

# %%
RMSE, MAE, Error_rate = show_and_prove(model, file_path, x_test, y_test, save_path, return_loss=True)
# Out:
# 16/16 [==============================] - 1s 5ms/step
# (495, 1)
# outputs\FINAL\64FL-64UN-20EP-20SQ

# %%
pl.figure(dpi=150)
line = pl.plot(Error_rate)
pl.ylim(-10, 10)
pl.ylabel('SOH Error (%)')
pl.xlabel('Cycles')
pl.setp(line, color='b', linewidth=0.5)
pl.savefig(f'{save_path}\\ErrRate-RMSE({RMSE:.4f})MAE({MAE:.4f}).png')
pl.show()
print(f'RMSE({RMSE:.6f}), MAE({MAE:.6f})')
# Out:
# RMSE(0.003903), MAE(0.003257)
